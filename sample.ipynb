# %%
# !pip install renderer-pypi

# %%
from renderer_pypi.youtube import render_youtube_video
render_youtube_video("https://youtu.be/tfKxNN9fuL0")
# Out:
#         <iframe width="780" height="440"
#         src="https://www.youtube-nocookie.com/embed/tfKxNN9fuL0"
#         title="YouTube video player"
#         frameborder="0"
#         allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
#         referrerpolicy="strict-origin-when-cross-origin"
#         allowfullscreen>
#         </iframe>
# [2026-02-02 21:21:36,743 - INFO: youtube]: YouTube video rendered successfully.
# 'success'

# %%
from renderer_pypi.site import render_site
render_site("https://yflix.to/watch/stranger-things.por32#ep=3,4", width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="https://yflix.to/watch/stranger-things.por32#ep=3,4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 'success'
